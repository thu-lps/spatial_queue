# %%
import numpy as np
import pandas as pd
import requests
import datetime, time
import matplotlib.pyplot as plt
import random

# %%
# 'useless' in case this code change our data as it is random
path = '../traffic_inputs/background_ods_day_for_Marin_new_change_marin_side_od_raw.csv' 
bg_od_df = pd.read_csv(path)

# %%
# 6:00-6:15 1155
# 6:15-6:30 1444
# 6:30-6:45 2022
# 6:45-7:00 2890
# 7:00-7:15 4332
# 7:15-7:30 5776
# 7:30-7:45 7510
# 7:45-8:00 10110
# 8:00-8:15 11553
# 8:15-8:30 10110
# 8:30-8:45 8665
# 8:45-9:00 7220
# 9:00-9:15 6355
# 9:15-9:30 5776
# 9:30-9:45 5200
# 9:45-10:00 4332
# 10:00-10:15 4044
# 10:15-10:30 3850
# 10:30-10:45 3850
# 10:45-11:00 3850

# %%
bg_od_df['departure_time2'] = bg_od_df['departure_time'].copy()
a = bg_od_df.loc[(bg_od_df['departure_time2'] >=0) & (bg_od_df['departure_time2'] < 900)].index.to_list()
selected_a = random.sample(a, 1166)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=900) & (bg_od_df['departure_time2'] < 1800)].index.to_list()
selected_a = random.sample(a, 2380)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=1800) & (bg_od_df['departure_time2'] < 2700)].index.to_list()
selected_a = random.sample(a, 3038)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=2700) & (bg_od_df['departure_time2'] < 3600)].index.to_list()
selected_a = random.sample(a, 2945)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=3600) & (bg_od_df['departure_time2'] < 4500)].index.to_list()
selected_a = random.sample(a, 8189)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=4500) & (bg_od_df['departure_time2'] < 5400)].index.to_list()
selected_a = random.sample(a, 13093)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=5400) & (bg_od_df['departure_time2'] < 6300)].index.to_list()
selected_a = random.sample(a, 16356)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=6300) & (bg_od_df['departure_time2'] < 7200)].index.to_list()
selected_a = random.sample(a, 17013)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=7200) & (bg_od_df['departure_time2'] < 8100)].index.to_list()
selected_a = random.sample(a, 16350)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=8100) & (bg_od_df['departure_time2'] < 9000)].index.to_list()
selected_a = random.sample(a, 17131)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=9000) & (bg_od_df['departure_time2'] < 9900)].index.to_list()
selected_a = random.sample(a, 19411)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=9900) & (bg_od_df['departure_time2'] < 10800)].index.to_list()
selected_a = random.sample(a, 23366)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=10800) & (bg_od_df['departure_time2'] < 11700)].index.to_list()
selected_a = random.sample(a, 21343)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=11700) & (bg_od_df['departure_time2'] < 12600)].index.to_list()
selected_a = random.sample(a, 18715)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=12600) & (bg_od_df['departure_time2'] < 13500)].index.to_list()
selected_a = random.sample(a, 16371)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=13500) & (bg_od_df['departure_time2'] < 14400)].index.to_list()
selected_a = random.sample(a, 14965)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=14400) & (bg_od_df['departure_time2'] < 15300)].index.to_list()
selected_a = random.sample(a, 11378)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=15300) & (bg_od_df['departure_time2'] < 16200)].index.to_list()
selected_a = random.sample(a, 7655)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

a = bg_od_df.loc[(bg_od_df['departure_time2'] >=16200) & (bg_od_df['departure_time2'] < 17100)].index.to_list()
selected_a = random.sample(a, 3835)
bg_od_df.loc[selected_a, 'departure_time2'] = bg_od_df.loc[selected_a, 'departure_time2'] + 900

bg_od_df.loc[(bg_od_df['departure_time'] >=18000), 'departure_time2'] =  bg_od_df.loc[(bg_od_df['departure_time'] >=18000), 'departure_time2'] - 1800

# %%
bg_od_time_df = pd.DataFrame(columns = ['time', 'count'])
for time in range(0, 19800, 900):
    count = len(bg_od_df.loc[(bg_od_df['departure_time2'] < time + 900) & (bg_od_df['departure_time2'] >= time)])
    bg_od_time_df = bg_od_time_df.append([{'time':time,'count':count}], ignore_index = True)

# %%
plt.figure()
plt.plot(bg_od_time_df['time'][:-2], bg_od_time_df['count'][:-2])
plt.xlabel('Departure time')
plt.ylabel('Number of ODs')
plt.xticks(np.arange(0, 18000, 1800), np.arange(0, 18000, 1800)/3600 + 6)

# %%
bg_od_df['departure_time'] = bg_od_df['departure_time2'].copy()
bg_od_df = bg_od_df[['origin_nid_old','destin_nid_old','departure_hour','departure_quarter','origin_nid','destin_nid','departure_time']].copy()
#bg_od_df.to_csv('./background_ods_day_for_Marin_new_change_marin_side_od.csv', index = False)

# %%
# 6:00-6:15 1155
# 6:15-6:30 1444
# 6:30-6:45 2022
# 6:45-7:00 2890

# 7:00-7:15 4332
# 7:15-7:30 5776
# 7:30-7:45 7510
# 7:45-8:00 10110

# 8:00-8:15 11553
# 8:15-8:30 10110
# 8:30-8:45 8665
# 8:45-9:00 7220

# 9:00-9:15 6355
# 9:15-9:30 5776
# 9:30-9:45 5200
# 9:45-10:00 4332

# 10:00-10:15 4044
# 10:15-10:30 3850
# 10:30-10:45 3850
# 10:45-11:00 3850

# 11:00-11:15 3900： 3500 正, 400 反
# 11:15-11:30 4100： 3500 正, 500 反
# 11:30-11:45 4300：3800 正, 500 反
# 11:45-12:00 4350：3800 正，550反

# 12:00-12:15 4500：3500 正，1000反
# 12:15-12:30 4600：3500 正，1100反
# 12:30-12:45 4800：3400 正，1400反
# 12:45-13:00 4900：3300 正，1600反

# 13:00-13:15 5200：2600 正，2600反
# 13:15-13:30 5300：2600 正，2700反
#13:30-13:45 5500：2600 正，2900反
# 13:45-14:00 5600：2600 正，3000反

# 14:00-14:15 5800：2000正，2800反
# 14:15-14:30 6000：2000正，4000反
# 14:30-14:45 6400：2000正，
# 14:45-15:00 6950：2000正

# 15:00-15:15 7000：2000正
# 15:15-15:30 7100：2000正
# 15:30-15:45 7000：2000正
# 15:45-16:00 6900：2000正

# 16:00-16:15 7500： 1000正
# 16:15-16:30 7800：
# 16:30-16:45 8400
# 16:45-17:00 9000

# 17:00-17:15 9000：全反
# 17:15-17:30 9500
# 17:30-17:45 9700
# 17:45-18:00 9500

# 18:00-18:15 8500：全反
# 18:15-18:30 8000
# 18:30-18:45 7500
# 18:45-19:00 7000

# 19:00-19:15 6500：全反
# 19:15-19:30 6000
# 19:30-19:45 5400
# 19:45-20:00 5000

# 20:00-20:15 4500：全反
# 20:15-20:30 4000
# 20:30-20:45 3500
# 20:45-21:00 3000

# 21:00-21:15 2500：全反
# 21:15-21:30 2000
# 21:30-21:45 1500
# 21:45-22:00 1155

# %%
y = [1155, 1444, 2022, 2890, 
     4332, 5776, 7510, 10110, 
     11553, 10110, 8665, 7220,
    6355, 5776, 5200, 4332, 
     4044, 3850, 3850, 3850, 
     3900, 4100, 4300, 4350, 
     4500, 4600, 4800, 4900, 
     5200, 5300, 5500, 5600, 
     5800, 6000, 6400, 6950,
    7000, 7100, 7000, 6900,
    7500, 7800, 8400, 9000,
    9000, 9500, 9700, 9500,
    8500, 8000, 7500, 7000,
    6500, 6000, 5400, 5000,
    4500, 4000, 3500, 3000,
    2500, 2000, 1500, 1155]
x = np.arange(len(y))
plt.figure()
plt.plot(x,y)
plt.xticks(np.arange(0, len(y)+1, 8), np.arange(0, len(y)/4+1, 2) + 6)

# %%
bg_od_df.head()

# %%
bg_od_df = pd.read_csv('../traffic_inputs/fairfax/background_ods_day_for_Marin_new_change_marin_side_od.csv' )
bg_od_df_pm = pd.DataFrame(columns = ['origin_nid_old','destin_nid_old','departure_hour','departure_quarter','origin_nid','destin_nid','departure_time'])
total_number = len(bg_od_df)
# 11:00-11:15 3900： 3500 正, 400 反
# 11:15-11:30 4100： 3500 正, 500 反
# 11:30-11:45 4300：3800 正, 500 反
# 11:45-12:00 4350：3800 正，550反

hour = 11
number_sample_list = [3500, 3500, 3800, 3800]
number_sample_reverse_list = [400,500,500,550]

for i in range(len(number_sample_list)):
    quarter = i
    number_sample = number_sample_list[i]
    number_sample_reverse = number_sample_reverse_list[i]
    
    tmp_df = bg_od_df.sample(frac = number_sample/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

# %%
bg_od_df_pm.head(1)
# Out:
#   origin_nid_old destin_nid_old departure_hour departure_quarter origin_nid  \
# 0           3238           9357              7                 0       2778
#
#   destin_nid departure_time
# 0       7840          18192

# %%
bg_od_df.loc[(bg_od_df['origin_nid'] == 2778) & (bg_od_df['destin_nid'] == 7840)]
# Out:
#        origin_nid_old  destin_nid_old  departure_hour  departure_quarter  \
# 33012            3238            9357               7                  0
#
#        origin_nid  destin_nid  departure_time
# 33012        2778        7840            3714

# %%
bg_od_df = pd.read_csv('../traffic_inputs/fairfax/background_ods_day_for_Marin_new_change_marin_side_od.csv' )
bg_od_df_pm = pd.DataFrame(columns = ['origin_nid_old','destin_nid_old','departure_hour','departure_quarter','origin_nid','destin_nid','departure_time'])
total_number = len(bg_od_df)
# 11:00-11:15 3900： 3500 正, 400 反
# 11:15-11:30 4100： 3500 正, 500 反
# 11:30-11:45 4300：3800 正, 500 反
# 11:45-12:00 4350：3800 正，550反

hour = 11
number_sample_list = [3500, 3500, 3800, 3800]
number_sample_reverse_list = [400,500,500,550]

for i in range(len(number_sample_list)):
    quarter = i
    number_sample = number_sample_list[i]
    number_sample_reverse = number_sample_reverse_list[i]
    
    tmp_df = bg_od_df.sample(frac = number_sample/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

    tmp_df = bg_od_df.sample(frac = number_sample_reverse/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    tmp_df = tmp_df.rename(columns = {'origin_nid_old': 'destin_nid_old', 'destin_nid_old':'origin_nid_old', 'origin_nid':'destin_nid', 'destin_nid':'origin_nid'})
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

    
# 12:00-12:15 4500：3500 正，1000反
# 12:15-12:30 4600：3500 正，1100反
# 12:30-12:45 4800：3400 正，1400反
# 12:45-13:00 4900：3300 正，1600反
hour = 12
number_sample_list = [3500, 3500, 3400, 3300]
number_sample_reverse_list = [1000,1100,1400,1600]

for i in range(len(number_sample_list)):
    quarter = i
    number_sample = number_sample_list[i]
    number_sample_reverse = number_sample_reverse_list[i]
    
    tmp_df = bg_od_df.sample(frac = number_sample/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

    tmp_df = bg_od_df.sample(frac = number_sample_reverse/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    tmp_df = tmp_df.rename(columns = {'origin_nid_old': 'destin_nid_old', 'destin_nid_old':'origin_nid_old', 'origin_nid':'destin_nid', 'destin_nid':'origin_nid'})
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

# 13:00-13:15 5200：2600 正，2600反
# 13:15-13:30 5300：2600 正，2700反
#13:30-13:45 5500：2600 正，2900反
# 13:45-14:00 5600：2600 正，3000反
hour = 13
number_sample_list = [2600, 2600, 2600, 2600]
number_sample_reverse_list = [2600,2700,2900,3000]

for i in range(len(number_sample_list)):
    quarter = i
    number_sample = number_sample_list[i]
    number_sample_reverse = number_sample_reverse_list[i]
    
    tmp_df = bg_od_df.sample(frac = number_sample/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

    tmp_df = bg_od_df.sample(frac = number_sample_reverse/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    tmp_df = tmp_df.rename(columns = {'origin_nid_old': 'destin_nid_old', 'destin_nid_old':'origin_nid_old', 'origin_nid':'destin_nid', 'destin_nid':'origin_nid'})
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)
    
# 14:00-14:15 5800：2000正，3800反
# 14:15-14:30 6000：2000正，4000反
# 14:30-14:45 6400：2000正，
# 14:45-15:00 6950：2000正
hour = 14
number_sample_list = [2000, 2000, 2000, 2000]
number_sample_reverse_list = [3800,4000,4400,4950]

for i in range(len(number_sample_list)):
    quarter = i
    number_sample = number_sample_list[i]
    number_sample_reverse = number_sample_reverse_list[i]
    
    tmp_df = bg_od_df.sample(frac = number_sample/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

    tmp_df = bg_od_df.sample(frac = number_sample_reverse/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    tmp_df = tmp_df.rename(columns = {'origin_nid_old': 'destin_nid_old', 'destin_nid_old':'origin_nid_old', 'origin_nid':'destin_nid', 'destin_nid':'origin_nid'})
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)
    
# 15:00-15:15 7000：2000正
# 15:15-15:30 7100：2000正
# 15:30-15:45 7000：2000正
# 15:45-16:00 6900：2000正
hour = 15
number_sample_list = [2000, 2000, 2000, 2000]
number_sample_reverse_list = [5000,5100,5000,4900]

for i in range(len(number_sample_list)):
    quarter = i
    number_sample = number_sample_list[i]
    number_sample_reverse = number_sample_reverse_list[i]
    
    tmp_df = bg_od_df.sample(frac = number_sample/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

    tmp_df = bg_od_df.sample(frac = number_sample_reverse/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    tmp_df = tmp_df.rename(columns = {'origin_nid_old': 'destin_nid_old', 'destin_nid_old':'origin_nid_old', 'origin_nid':'destin_nid', 'destin_nid':'origin_nid'})
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)
    
# 16:00-16:15 7500： 1000正
# 16:15-16:30 7800：
# 16:30-16:45 8400
# 16:45-17:00 9000

hour = 16
number_sample_list = [1000, 1000, 1000, 1000]
number_sample_reverse_list = [6500,6800,7400,8000]

for i in range(len(number_sample_list)):
    quarter = i
    number_sample = number_sample_list[i]
    number_sample_reverse = number_sample_reverse_list[i]
    
    tmp_df = bg_od_df.sample(frac = number_sample/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

    tmp_df = bg_od_df.sample(frac = number_sample_reverse/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    tmp_df = tmp_df.rename(columns = {'origin_nid_old': 'destin_nid_old', 'destin_nid_old':'origin_nid_old', 'origin_nid':'destin_nid', 'destin_nid':'origin_nid'})
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)
    
# 17:00-17:15 9000：全反
# 17:15-17:30 9500
# 17:30-17:45 9700
# 17:45-18:00 9500
hour = 17
number_sample_reverse_list = [9000,9500,9700,9500]
for i in range(len(number_sample_list)):
    quarter = i
    number_sample_reverse = number_sample_reverse_list[i]
    
    tmp_df = bg_od_df.sample(frac = number_sample_reverse/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    tmp_df = tmp_df.rename(columns = {'origin_nid_old': 'destin_nid_old', 'destin_nid_old':'origin_nid_old', 'origin_nid':'destin_nid', 'destin_nid':'origin_nid'})
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

# 18:00-18:15 8500：全反
# 18:15-18:30 8000
# 18:30-18:45 7500
# 18:45-19:00 7000
hour = 18
number_sample_reverse_list = [8500,8000,7500,7000]
for i in range(len(number_sample_list)):
    quarter = i
    number_sample_reverse = number_sample_reverse_list[i]
    
    tmp_df = bg_od_df.sample(frac = number_sample_reverse/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    tmp_df = tmp_df.rename(columns = {'origin_nid_old': 'destin_nid_old', 'destin_nid_old':'origin_nid_old', 'origin_nid':'destin_nid', 'destin_nid':'origin_nid'})
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

# 19:00-19:15 6500：全反
# 19:15-19:30 6000
# 19:30-19:45 5400
# 19:45-20:00 5000
hour = 19
number_sample_reverse_list = [6500,6000,5400,5000]
for i in range(len(number_sample_list)):
    quarter = i
    number_sample_reverse = number_sample_reverse_list[i]
    
    tmp_df = bg_od_df.sample(frac = number_sample_reverse/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    tmp_df = tmp_df.rename(columns = {'origin_nid_old': 'destin_nid_old', 'destin_nid_old':'origin_nid_old', 'origin_nid':'destin_nid', 'destin_nid':'origin_nid'})
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

# 20:00-20:15 4500：全反
# 20:15-20:30 4000
# 20:30-20:45 3500
# 20:45-21:00 3000
hour = 20
number_sample_reverse_list = [4500,4000,3500,3000]
for i in range(len(number_sample_list)):
    quarter = i
    number_sample_reverse = number_sample_reverse_list[i]
    
    tmp_df = bg_od_df.sample(frac = number_sample_reverse/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    tmp_df = tmp_df.rename(columns = {'origin_nid_old': 'destin_nid_old', 'destin_nid_old':'origin_nid_old', 'origin_nid':'destin_nid', 'destin_nid':'origin_nid'})
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

# 21:00-21:15 2500：全反
# 21:15-21:30 2000
# 21:30-21:45 1500
# 21:45-22:00 1155
hour = 21
number_sample_reverse_list = [2500,2000,1500,1155]
for i in range(len(number_sample_list)):
    quarter = i
    number_sample_reverse = number_sample_reverse_list[i]
    
    tmp_df = bg_od_df.sample(frac = number_sample_reverse/total_number)
    tmp_df['departure_time'] = tmp_df['departure_time'].apply(lambda x: random.randint((hour-6) * 3600 + quarter * 900, (hour-6) * 3600 + (quarter+1) * 900))
    tmp_df = tmp_df.rename(columns = {'origin_nid_old': 'destin_nid_old', 'destin_nid_old':'origin_nid_old', 'origin_nid':'destin_nid', 'destin_nid':'origin_nid'})
    bg_od_df_pm = pd.concat((bg_od_df_pm, tmp_df), ignore_index = True)

# %%
bg_od_df_pm.head(1)

# %%
print(len(bg_od_df_pm))
print(len(bg_od_df))

# %%
bg_od_df = pd.concat((bg_od_df, bg_od_df_pm), ignore_index = True)

# %%
bg_od_time_df = pd.DataFrame(columns = ['time', 'count'])
for time in range(0, 57601, 900):
    count = len(bg_od_df.loc[(bg_od_df['departure_time'] < time + 900) & (bg_od_df['departure_time'] >= time)])
    bg_od_time_df = bg_od_time_df.append([{'time':time,'count':count}], ignore_index = True)

# %%
plt.figure()
plt.plot(bg_od_time_df['time'][:-2], bg_od_time_df['count'][:-2])
plt.xlabel('Departure time')
plt.ylabel('Number of ODs')
plt.xticks(np.arange(0, 57601, 7200), (np.arange(0, 57601, 7200)/3600 + 6).astype('int'))

# %%
bg_od_df_pm.head()

# %%
#bg_od_df.to_csv('../traffic_inputs/background_ods_day_for_Marin_new_change_marin_side_od_add_afternoon.csv', index = False)
